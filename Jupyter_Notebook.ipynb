# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Title:
# Proyect Final

# %% [markdown]
# Introducction:
# Hello, my name is Marcello Flores; and then I will perform the exercises proposed for my final project of the course.

# %% [markdown]
# Languages ​​used in Data Science:
# 1. Python
# 2. SQL
# 3. JAVA
# 4. MATLAB

# %% [markdown]
# Libraries used in Data Science:
# * Pandas
# * Numpy
# * MathPlotlib

# %% [markdown]
# Data Science Tool Table:
# | Tool                | Type            | Common Uses                  |
# |---------------------|----------------|------------------------------|
# | Jupyterlite Notebook     | Environment     | Interactive analysis         |
# | SQL          | Processing     | data control                |
# | Git-hub                 | Version Control  | Code management              |
# | Apache Spark        | Processing      | Big data analysis            |

# %% [markdown]
# Arithmetic examples:
# - Addition: 2 + 4 = 6
# - Subtraction: 9 - 7 = 2
# - Multiplication: 5 * 2 = 10
# - Division: 20 / 5 = 4

# %% [markdown]
# Multiplication and Addition:
#
# Example = (4 + 4) * 7

# %% [markdown]
# From minutes to hours:
# - minutes = 60
# - hours = minutes / 60

# %% [markdown]
# Author:
# Marcello Flores
